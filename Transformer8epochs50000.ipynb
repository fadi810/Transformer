# %%
# !pip install tiktoken
# !pip install -U datasets
# Out:
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2025.4.26)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.31.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import tiktoken
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import os
import urllib.request
import tiktoken
import pandas
from datasets import load_dataset

# %% [markdown]
# ### Loading the dataset
#  * Turning dataset from pandas into String for sliding windwo
#  * creating a sliding window using the create_dataloader

# %%
### Data Loading

class GPTDatasetV1(Dataset):
    """Dataset for GPT-style text generation using sliding window chunks

    Implements:
    - Context windowing with specified stride
    - Input/target sequence creation
    - Special token handling

    Handles:
    - Settings token ids using tiktoken
    """
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []

        # Tokenize the entire text
        token_ids = tokenizer.encode(txt, allowed_special={"<|endoftext|>"})

        # Use a sliding window to chunk the book into overlapping sequences of max_length
        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i:i + max_length]             # Current context window
            target_chunk = token_ids[i + 1: i + max_length + 1]   # Next token prediction
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]


def create_dataloader_v1(txt, batch_size=4, max_length=256,stride=128, shuffle=True, drop_last=True, num_workers=0):
    """Creates DataLoader with proper batching and shuffling"""
    # Initialize the tokenizer
    tokenizer = tiktoken.get_encoding("gpt2")

    # Create dataset
    dataset = GPTDatasetV1(txt, tokenizer, max_length, stride)

    # Create dataloader
    dataloader = DataLoader(
        dataset, batch_size=batch_size, shuffle=shuffle, drop_last=drop_last, num_workers=num_workers)

    return dataloader

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_in, d_out, context_length, dropout, num_heads, qkv_bias=False):
        super().__init__()
        assert d_out % num_heads == 0, "d_out must be divisible by num_heads"

        self.d_out = d_out          # Output dimension
        self.num_heads = num_heads   # Number of attention heads
        self.head_dim = d_out // num_heads  # Dimension of each head's output

        # Linear transformations for Q, K, V
        self.W_query = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_key = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_value = nn.Linear(d_in, d_out, bias=qkv_bias)

        # Final output projection
        self.out_proj = nn.Linear(d_out, d_out)
        self.dropout = nn.Dropout(dropout)

        # Causal mask to prevent attending to future tokens
        self.register_buffer('mask', torch.triu(torch.ones(context_length, context_length), diagonal=1))

    def forward(self, x):
        # x shape: (batch_size, num_tokens, d_in)
        b, num_tokens, d_in = x.shape

        # Project input to query, key, value
        keys = self.W_key(x)       # Shape: (b, num_tokens, d_out)
        queries = self.W_query(x)  # Shape: (b, num_tokens, d_out)
        values = self.W_value(x)   # Shape: (b, num_tokens, d_out)

        # Reshape into multiple heads
        keys = keys.view(b, num_tokens, self.num_heads, self.head_dim)
        values = values.view(b, num_tokens, self.num_heads, self.head_dim)
        queries = queries.view(b, num_tokens, self.num_heads, self.head_dim)

        # Transpose to get dimensions (batch_size, num_heads, num_tokens, head_dim)
        keys = keys.transpose(1, 2)
        queries = queries.transpose(1, 2)
        values = values.transpose(1, 2)

        # Compute scaled dot-product attention
        attn_scores = queries @ keys.transpose(2, 3)  # Dot product for each head

        # Apply causal mask
        mask_bool = self.mask.bool()[:num_tokens, :num_tokens]
        attn_scores.masked_fill_(mask_bool, -torch.inf)

        # Softmax and dropout
        attn_weights = torch.softmax(attn_scores / keys.shape[-1]**0.5, dim=-1)
        attn_weights = self.dropout(attn_weights)

        # Weighted sum of values
        context_vec = (attn_weights @ values).transpose(1, 2)

        # Combine heads
        context_vec = context_vec.contiguous().view(b, num_tokens, self.d_out)
        context_vec = self.out_proj(context_vec)  # Final projection

        return context_vec

# %%
class LayerNorm(nn.Module):
    def __init__(self, emb_dim):
        super().__init__()
        self.eps = 1e-5
        self.scale = nn.Parameter(torch.ones(emb_dim))
        self.shift = nn.Parameter(torch.zeros(emb_dim))

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)
        var = x.var(dim=-1, keepdim=True, unbiased=False)
        norm_x = (x - mean) / torch.sqrt(var + self.eps)
        return self.scale * norm_x + self.shift


class GELU(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return 0.5 * x * (1 + torch.tanh(
            torch.sqrt(torch.tensor(2.0 / torch.pi)) *
            (x + 0.044715 * torch.pow(x, 3))
        ))


class FeedForward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(cfg["emb_dim"], 4 * cfg["emb_dim"]),
            GELU(),
            nn.Linear(4 * cfg["emb_dim"], cfg["emb_dim"]),
        )

    def forward(self, x):
        return self.layers(x)


class TransformerBlock(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.att = MultiHeadAttention(
            d_in=cfg["emb_dim"],
            d_out=cfg["emb_dim"],
            context_length=cfg["context_length"],
            num_heads=cfg["n_heads"],
            dropout=cfg["drop_rate"],
            qkv_bias=cfg["qkv_bias"])
        self.ff = FeedForward(cfg)
        self.norm1 = LayerNorm(cfg["emb_dim"])
        self.norm2 = LayerNorm(cfg["emb_dim"])
        self.drop_shortcut = nn.Dropout(cfg["drop_rate"])

    def forward(self, x):
        # Shortcut connection for attention block
        shortcut = x
        x = self.norm1(x)
        x = self.att(x)   # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        # Shortcut connection for feed-forward block
        shortcut = x
        x = self.norm2(x)
        x = self.ff(x)
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        return x


class GPTModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.tok_emb = nn.Embedding(cfg["vocab_size"], cfg["emb_dim"])
        self.pos_emb = nn.Embedding(cfg["context_length"], cfg["emb_dim"])
        self.drop_emb = nn.Dropout(cfg["drop_rate"])

        self.trf_blocks = nn.Sequential(
            *[TransformerBlock(cfg) for _ in range(cfg["n_layers"])])

        self.final_norm = LayerNorm(cfg["emb_dim"])
        self.out_head = nn.Linear(cfg["emb_dim"], cfg["vocab_size"], bias=False)

    def forward(self, in_idx):
        batch_size, seq_len = in_idx.shape
        tok_embeds = self.tok_emb(in_idx)
        pos_embeds = self.pos_emb(torch.arange(seq_len, device=in_idx.device))
        x = tok_embeds + pos_embeds  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_emb(x)
        x = self.trf_blocks(x)
        x = self.final_norm(x)
        logits = self.out_head(x)
        return logits


def generate_text_simple(model, idx, max_new_tokens, context_size):
    # idx is (B, T) array of indices in the current context
    for _ in range(max_new_tokens):

        # Crop current context if it exceeds the supported context size
        # E.g., if LLM supports only 5 tokens, and the context size is 10
        # then only the last 5 tokens are used as context
        idx_cond = idx[:, -context_size:]

        # Get the predictions
        with torch.no_grad():
            logits = model(idx_cond)

        # Focus only on the last time step
        # (batch, n_token, vocab_size) becomes (batch, vocab_size)
        logits = logits[:, -1, :]

        # Get the idx of the vocab entry with the highest logits value
        idx_next = torch.argmax(logits, dim=-1, keepdim=True)  # (batch, 1)

        # Append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch, n_tokens+1)

    return idx

# %%
def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text)
    encoded_tensor = torch.tensor(encoded).unsqueeze(0)  # add batch dimension
    return encoded_tensor


def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0)  # remove batch dimension
    return tokenizer.decode(flat.tolist())


def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch, target_batch = input_batch.to(device), target_batch.to(device)
    logits = model(input_batch)
    loss = torch.nn.functional.cross_entropy(logits.flatten(0, 1), target_batch.flatten())
    return loss


def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches


def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    model.train()
    return train_loss, val_loss


def generate_and_print_sample(model, tokenizer, device, start_context):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded,
            max_new_tokens=100, context_size=context_size
        )
        decoded_text = token_ids_to_text(token_ids, tokenizer)
        print(decoded_text.replace("\n", " "))  # Compact print format
    return decoded_text
    model.train()


def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen = 0
    global_step = -1

    # Main training loop
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode

        for input_batch, target_batch in train_loader:
            optimizer.zero_grad()  # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward()  # Calculate loss gradients
            optimizer.step()  # Update model weights using loss gradients
            tokens_seen += input_batch.numel()
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")

        # Print a sample text after each epoch
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )
        torch.save(model.state_dict(), "model.pth")
        save_path = '/content/drive/MyDrive/model_weights.pth'
        torch.save(model.state_dict(), save_path)

    return train_losses, val_losses, track_tokens_seen


def plot_losses(epochs_seen, tokens_seen, train_losses, val_losses):
    fig, ax1 = plt.subplots()

    # Plot training and validation loss against epochs
    ax1.plot(epochs_seen, train_losses, label="Training loss")
    ax1.plot(epochs_seen, val_losses, linestyle="-.", label="Validation loss")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")
    ax1.legend(loc="upper right")

    # Create a second x-axis for tokens seen
    ax2 = ax1.twiny()  # Create a second x-axis that shares the same y-axis
    ax2.plot(tokens_seen, train_losses, alpha=0)  # Invisible plot for aligning ticks
    ax2.set_xlabel("Tokens seen")

    fig.tight_layout()  # Adjust layout to make room
    # plt.show()




def main(gpt_config, settings,text_data):

    torch.manual_seed(123)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


    text_data = "".join(df[:50000])

    ##############################
    # Initialize model
    ##############################

    model = GPTModel(gpt_config)
    model.load_state_dict(torch.load('/content/drive/MyDrive/model_weights.pth', weights_only=True))
    model.to(device)
    optimizer = torch.optim.AdamW(
        model.parameters(), lr=settings["learning_rate"], weight_decay=settings["weight_decay"]
    )

    ##############################
    # Set up dataloaders
    ##############################

    # Train/validation ratio
    train_ratio = 0.90
    split_idx = int(train_ratio * len(text_data))

    train_loader = create_dataloader_v1(
        text_data[:split_idx],
        batch_size=settings["batch_size"],
        max_length=gpt_config["context_length"],
        stride=gpt_config["context_length"],
        drop_last=True,
        shuffle=True,
        num_workers=0
    )

    val_loader = create_dataloader_v1(
        text_data[split_idx:],
        batch_size=settings["batch_size"],
        max_length=gpt_config["context_length"],
        stride=gpt_config["context_length"],
        drop_last=False,
        shuffle=False,
        num_workers=0
    )

    ##############################
    # Train model
    ##############################

    tokenizer = tiktoken.get_encoding("gpt2")

    train_losses, val_losses, tokens_seen = train_model_simple(
        model, train_loader, val_loader, optimizer, device,
        num_epochs=settings["num_epochs"], eval_freq=5, eval_iter=1,
        start_context="Once upon a time", tokenizer=tokenizer
    )

    return train_losses, val_losses, tokens_seen, model

# %%
from google.colab import drive
drive.mount('/content/drive')

if __name__ == "__main__":

    GPT_CONFIG_124M = {
        "vocab_size": 50257,    # Vocabulary size
        "context_length": 256,  # Shortened context length (orig: 1024)
        "emb_dim": 768,         # Embedding dimension
        "n_heads": 12,          # Number of attention heads
        "n_layers": 12,         # Number of layers
        "drop_rate": 0.1,       # Dropout rate
        "qkv_bias": False       # Query-key-value bias
    }

    OTHER_SETTINGS = {
        "learning_rate": 5e-4,
        "num_epochs": 5,
        "batch_size": 8,
        "weight_decay": 0.1
    }

    ###########################
    # Initiate training
    ###########################

    df = load_dataset("roneneldan/TinyStories")
    df= df['train'].to_pandas(batch_size=50000)
    df = df['text'].to_list()

    train_losses, val_losses, tokens_seen, model = main(GPT_CONFIG_124M, OTHER_SETTINGS,df)

    ###########################
    # After training
    ###########################

    # Plot results
    epochs_tensor = torch.linspace(0, OTHER_SETTINGS["num_epochs"], len(train_losses))
    plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses)
    plt.savefig("loss.pdf")


    # Save and load model
    torch.save(model.state_dict(), "model.pth")
    model = GPTModel(GPT_CONFIG_124M)
    model.load_state_dict(torch.load("model.pth", weights_only=True))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Ep 1 (Step 000000): Train loss 9.337, Val loss 9.229
# Ep 1 (Step 000005): Train loss 7.229, Val loss 7.108
# Ep 1 (Step 000010): Train loss 6.130, Val loss 6.026
# Ep 1 (Step 000015): Train loss 5.656, Val loss 5.666
# Ep 1 (Step 000020): Train loss 5.603, Val loss 5.648
# Ep 1 (Step 000025): Train loss 5.381, Val loss 5.505
# Ep 1 (Step 000030): Train loss 5.258, Val loss 5.301
# Ep 1 (Step 000035): Train loss 4.946, Val loss 5.166
# Ep 1 (Step 000040): Train loss 4.903, Val loss 4.997
# Ep 1 (Step 000045): Train loss 5.288, Val loss 4.856
# Ep 1 (Step 000050): Train loss 4.638, Val loss 4.775
# Ep 1 (Step 000055): Train loss 5.038, Val loss 4.643
# Ep 1 (Step 000060): Train loss 4.866, Val loss 4.624
# Ep 1 (Step 000065): Train loss 4.880, Val loss 4.601
# Ep 1 (Step 000070): Train loss 4.846, Val loss 4.528
# Ep 1 (Step 000075): Train loss 4.630, Val loss 4.499
# Ep 1 (Step 000080): Train loss 4.306, Val loss 4.471
# Ep 1 (Step 000085): Train loss 4.551, Val loss 4.441
# Ep 1 (Step 000090): Train loss 4.480, Val loss 4.419
# Ep 1 (Step 000095): Train loss 4.512, Val loss 4.391
# Ep 1 (Step 000100): Train loss 4.299, Val loss 4.381
# Ep 1 (Step 000105): Train loss 4.300, Val loss 4.315
# Ep 1 (Step 000110): Train loss 4.487, Val loss 4.292
# Ep 1 (Step 000115): Train loss 4.548, Val loss 4.236
# Ep 1 (Step 000120): Train loss 4.530, Val loss 4.231
# Ep 1 (Step 000125): Train loss 4.210, Val loss 4.201
# Ep 1 (Step 000610): Train loss 3.444, Val loss 3.285
# Ep 1 (Step 000615): Train loss 3.607, Val loss 3.296
# Ep 1 (Step 000620): Train loss 3.447, Val loss 3.218
# Ep 1 (Step 000625): Train loss 3.654, Val loss 3.214
# Ep 1 (Step 000630): Train loss 3.387, Val loss 3.224
# Ep 1 (Step 000635): Train loss 3.481, Val loss 3.235
# Ep 1 (Step 000640): Train loss 3.379, Val loss 3.221
# Ep 1 (Step 000645): Train loss 3.181, Val loss 3.211
# Ep 1 (Step 000650): Train loss 3.686, Val loss 3.272
# Ep 1 (Step 000655): Train loss 3.578, Val loss 3.219
# Ep 1 (Step 000660): Train loss 3.250, Val loss 3.201
# Ep 1 (Step 000665): Train loss 3.638, Val loss 3.262
# Ep 1 (Step 000670): Train loss 3.392, Val loss 3.235
# Ep 1 (Step 000675): Train loss 3.425, Val loss 3.209
# Ep 1 (Step 000680): Train loss 3.207, Val loss 3.215
# Ep 1 (Step 000685): Train loss 3.341, Val loss 3.179
# Ep 1 (Step 000690): Train loss 3.287, Val loss 3.187
# Ep 1 (Step 000695): Train loss 3.363, Val loss 3.185
# Ep 1 (Step 000700): Train loss 3.357, Val loss 3.185
# Ep 1 (Step 000705): Train loss 3.579, Val loss 3.174
# Ep 1 (Step 000710): Train loss 3.666, Val loss 3.209
# Ep 1 (Step 000715): Train loss 3.470, Val loss 3.206
# Ep 1 (Step 000720): Train loss 3.305, Val loss 3.188
# Ep 1 (Step 000725): Train loss 3.587, Val loss 3.191
# Ep 1 (Step 000730): Train loss 3.508, Val loss 3.158
# Ep 1 (Step 000735): Train loss 3.214, Val loss 3.179
# Ep 1 (Step 000740): Train loss 3.344, Val loss 3.160
# Ep 1 (Step 000745): Train loss 3.323, Val loss 3.156
# Ep 1 (Step 000750): Train loss 3.113, Val loss 3.164
# Ep 1 (Step 000755): Train loss 3.384, Val loss 3.172
# Ep 1 (Step 000760): Train loss 3.329, Val loss 3.165
# Ep 1 (Step 000765): Train loss 3.014, Val loss 3.162
# Ep 1 (Step 000770): Train loss 3.221, Val loss 3.142
# Ep 1 (Step 000775): Train loss 3.316, Val loss 3.170
# Ep 1 (Step 000780): Train loss 3.666, Val loss 3.155
# Ep 1 (Step 000785): Train loss 3.373, Val loss 3.166
# Ep 1 (Step 000790): Train loss 3.132, Val loss 3.150
# Ep 1 (Step 000795): Train loss 3.138, Val loss 3.151
# Ep 1 (Step 000800): Train loss 3.555, Val loss 3.155
# Ep 1 (Step 000805): Train loss 3.211, Val loss 3.144
# Ep 1 (Step 000810): Train loss 3.258, Val loss 3.206
# Ep 1 (Step 000815): Train loss 3.309, Val loss 3.159
# Ep 1 (Step 000820): Train loss 3.315, Val loss 3.114
# Ep 1 (Step 000825): Train loss 3.312, Val loss 3.163
# Ep 1 (Step 000830): Train loss 3.112, Val loss 3.149
# Ep 1 (Step 000835): Train loss 3.227, Val loss 3.137
# Ep 1 (Step 000840): Train loss 3.080, Val loss 3.125
# Ep 1 (Step 000845): Train loss 3.211, Val loss 3.102
# Ep 1 (Step 000850): Train loss 3.437, Val loss 3.096
# Ep 1 (Step 000855): Train loss 3.189, Val loss 3.120
# Ep 1 (Step 000860): Train loss 3.035, Val loss 3.116
# Ep 1 (Step 000865): Train loss 3.385, Val loss 3.110
# Ep 1 (Step 000870): Train loss 3.127, Val loss 3.120
# Ep 1 (Step 000875): Train loss 3.327, Val loss 3.124
# Ep 1 (Step 000880): Train loss 3.337, Val loss 3.157
# Ep 1 (Step 000885): Train loss 3.286, Val loss 3.107
# Ep 1 (Step 000890): Train loss 3.448, Val loss 3.130
# Ep 1 (Step 000895): Train loss 3.158, Val loss 3.073
# Ep 1 (Step 000900): Train loss 3.035, Val loss 3.085
# Ep 1 (Step 000905): Train loss 3.276, Val loss 3.077
# Ep 1 (Step 000910): Train loss 3.467, Val loss 3.072
# Ep 1 (Step 000915): Train loss 3.155, Val loss 3.089
# Ep 1 (Step 000920): Train loss 3.110, Val loss 3.052
# Ep 1 (Step 000925): Train loss 3.460, Val loss 3.079
# Ep 1 (Step 000930): Train loss 3.201, Val loss 3.092
# Ep 1 (Step 000935): Train loss 2.997, Val loss 3.092
# Ep 1 (Step 000940): Train loss 3.331, Val loss 3.090
# Ep 1 (Step 000945): Train loss 3.300, Val loss 3.049
# Ep 1 (Step 000950): Train loss 3.282, Val loss 3.066
# Ep 1 (Step 000955): Train loss 3.474, Val loss 3.067
# Ep 1 (Step 000960): Train loss 3.263, Val loss 3.053
# Ep 1 (Step 000965): Train loss 3.260, Val loss 3.050
# Ep 1 (Step 000970): Train loss 3.552, Val loss 3.075
# Ep 1 (Step 000975): Train loss 3.166, Val loss 3.050
# Ep 1 (Step 000980): Train loss 3.038, Val loss 3.013
# Ep 1 (Step 000985): Train loss 3.266, Val loss 3.026
# Ep 1 (Step 000990): Train loss 3.126, Val loss 3.045
# Ep 1 (Step 000995): Train loss 3.129, Val loss 3.016
# Ep 1 (Step 001000): Train loss 3.145, Val loss 3.011
# Ep 1 (Step 001005): Train loss 3.370, Val loss 3.031
# Ep 1 (Step 001010): Train loss 2.926, Val loss 3.054
# Ep 1 (Step 001015): Train loss 3.189, Val loss 3.025
# Ep 1 (Step 001020): Train loss 3.132, Val loss 3.037
# Ep 1 (Step 001025): Train loss 3.398, Val loss 2.991
# Ep 1 (Step 001030): Train loss 2.888, Val loss 2.984
# Ep 1 (Step 001035): Train loss 3.297, Val loss 3.005
# Ep 1 (Step 001040): Train loss 3.102, Val loss 2.993
# Ep 1 (Step 001045): Train loss 3.103, Val loss 3.004
# Ep 1 (Step 001050): Train loss 3.491, Val loss 2.941
# Ep 1 (Step 001055): Train loss 3.286, Val loss 2.947
# Ep 1 (Step 001060): Train loss 3.215, Val loss 2.953
# Ep 1 (Step 001065): Train loss 3.182, Val loss 2.960
# Ep 1 (Step 001070): Train loss 3.173, Val loss 2.949
# Ep 1 (Step 001075): Train loss 3.141, Val loss 2.964
# Ep 1 (Step 001080): Train loss 3.026, Val loss 2.964
# Ep 1 (Step 001085): Train loss 3.136, Val loss 2.951
# Ep 1 (Step 001090): Train loss 3.232, Val loss 2.966
# Ep 1 (Step 001095): Train loss 2.931, Val loss 2.961
# Ep 1 (Step 001100): Train loss 3.263, Val loss 2.970
# Ep 1 (Step 001105): Train loss 3.496, Val loss 2.950
# Ep 1 (Step 001110): Train loss 3.220, Val loss 2.958
# Ep 1 (Step 001115): Train loss 3.488, Val loss 2.958
# Ep 1 (Step 001120): Train loss 3.027, Val loss 2.956
# Ep 1 (Step 001125): Train loss 3.051, Val loss 2.971
# Ep 1 (Step 001130): Train loss 3.168, Val loss 2.964
# Ep 1 (Step 001135): Train loss 3.230, Val loss 2.971
# Ep 1 (Step 001140): Train loss 3.006, Val loss 2.958
# Ep 1 (Step 001145): Train loss 3.155, Val loss 2.968
# Ep 1 (Step 001150): Train loss 2.996, Val loss 2.921
# Ep 1 (Step 001155): Train loss 3.120, Val loss 2.917
# Ep 1 (Step 001160): Train loss 3.154, Val loss 2.942
# Ep 1 (Step 001165): Train loss 3.203, Val loss 2.921
# Ep 1 (Step 001170): Train loss 3.218, Val loss 2.933
# Ep 1 (Step 001175): Train loss 3.229, Val loss 2.907
# Ep 1 (Step 001180): Train loss 3.284, Val loss 2.893
# Ep 1 (Step 001185): Train loss 3.085, Val loss 2.911
# Ep 1 (Step 001190): Train loss 3.102, Val loss 2.927
# Ep 1 (Step 001195): Train loss 3.126, Val loss 2.890
# Ep 1 (Step 001200): Train loss 3.171, Val loss 2.922
# Ep 1 (Step 001205): Train loss 3.168, Val loss 2.917
# Ep 1 (Step 001210): Train loss 3.144, Val loss 2.937
# Ep 1 (Step 001215): Train loss 3.096, Val loss 2.936
# Ep 1 (Step 001220): Train loss 3.219, Val loss 2.901
# Ep 1 (Step 001225): Train loss 3.129, Val loss 2.908
# Ep 1 (Step 001230): Train loss 3.287, Val loss 2.894
# Ep 1 (Step 001235): Train loss 3.066, Val loss 2.921
# Ep 1 (Step 001240): Train loss 3.107, Val loss 2.903
# Ep 1 (Step 001245): Train loss 3.379, Val loss 2.867
# Ep 1 (Step 001250): Train loss 2.988, Val loss 2.866
# Ep 1 (Step 001255): Train loss 3.310, Val loss 2.889
# Ep 1 (Step 001260): Train loss 3.110, Val loss 2.871
# Ep 1 (Step 001265): Train loss 3.300, Val loss 2.868
# Ep 1 (Step 001270): Train loss 3.087, Val loss 2.850
# Ep 1 (Step 001275): Train loss 3.142, Val loss 2.851
# Ep 1 (Step 001280): Train loss 2.961, Val loss 2.836
# Ep 1 (Step 001285): Train loss 3.102, Val loss 2.851
# Ep 1 (Step 001290): Train loss 3.011, Val loss 2.873
# Ep 1 (Step 001295): Train loss 2.938, Val loss 2.884
# Ep 1 (Step 001300): Train loss 3.024, Val loss 2.881
# Ep 1 (Step 001305): Train loss 2.982, Val loss 2.875
# Ep 1 (Step 001310): Train loss 2.997, Val loss 2.878
# Ep 1 (Step 001315): Train loss 2.892, Val loss 2.847
# Ep 1 (Step 001320): Train loss 2.973, Val loss 2.852
# Ep 1 (Step 001805): Train loss 2.888, Val loss 2.698
# Ep 1 (Step 001810): Train loss 2.916, Val loss 2.707
# Ep 1 (Step 001815): Train loss 2.671, Val loss 2.711
# Ep 1 (Step 001820): Train loss 2.764, Val loss 2.710
# Ep 1 (Step 001825): Train loss 2.951, Val loss 2.707
# Ep 1 (Step 001830): Train loss 3.064, Val loss 2.706
# Ep 1 (Step 001835): Train loss 3.066, Val loss 2.700
# Ep 1 (Step 001840): Train loss 2.830, Val loss 2.692
# Ep 1 (Step 001845): Train loss 2.906, Val loss 2.691
# Ep 1 (Step 001850): Train loss 2.821, Val loss 2.699
# Ep 1 (Step 001855): Train loss 2.876, Val loss 2.709
# Ep 1 (Step 001860): Train loss 3.035, Val loss 2.699
# Ep 1 (Step 001865): Train loss 3.056, Val loss 2.699
# Ep 1 (Step 001870): Train loss 2.916, Val loss 2.729
# Ep 1 (Step 001875): Train loss 2.879, Val loss 2.727
# Ep 1 (Step 001880): Train loss 2.905, Val loss 2.717
# Ep 1 (Step 001885): Train loss 2.758, Val loss 2.689
# Ep 1 (Step 001890): Train loss 2.961, Val loss 2.676
# Ep 1 (Step 001895): Train loss 2.751, Val loss 2.676
# Ep 1 (Step 001900): Train loss 3.004, Val loss 2.678
# Ep 1 (Step 001905): Train loss 2.974, Val loss 2.667
# Ep 1 (Step 001910): Train loss 3.034, Val loss 2.646
# Ep 1 (Step 001915): Train loss 3.006, Val loss 2.669
# Ep 1 (Step 001920): Train loss 2.673, Val loss 2.660
# Ep 1 (Step 001925): Train loss 2.674, Val loss 2.691
# Ep 1 (Step 001930): Train loss 3.015, Val loss 2.705
# Ep 1 (Step 001935): Train loss 2.853, Val loss 2.684
# Ep 1 (Step 001940): Train loss 2.657, Val loss 2.682
# Ep 1 (Step 001945): Train loss 2.910, Val loss 2.697
# Ep 1 (Step 001950): Train loss 3.147, Val loss 2.684
# Ep 1 (Step 001955): Train loss 2.790, Val loss 2.688
# Ep 1 (Step 001960): Train loss 2.949, Val loss 2.655
# Ep 1 (Step 001965): Train loss 2.837, Val loss 2.646
# Ep 1 (Step 001970): Train loss 2.933, Val loss 2.632
# Ep 1 (Step 001975): Train loss 3.052, Val loss 2.630
# Ep 1 (Step 001980): Train loss 2.571, Val loss 2.608
# Ep 1 (Step 001985): Train loss 2.551, Val loss 2.612
# Ep 1 (Step 001990): Train loss 2.944, Val loss 2.637
# Ep 1 (Step 001995): Train loss 2.883, Val loss 2.636
# Ep 1 (Step 002000): Train loss 2.631, Val loss 2.649
# Ep 1 (Step 002005): Train loss 2.844, Val loss 2.655
# Ep 1 (Step 002010): Train loss 2.682, Val loss 2.641
# Ep 1 (Step 002015): Train loss 2.771, Val loss 2.616
# Ep 1 (Step 002020): Train loss 2.796, Val loss 2.612
# Ep 1 (Step 002025): Train loss 2.648, Val loss 2.613
# Ep 1 (Step 002030): Train loss 2.784, Val loss 2.591
# Ep 1 (Step 002035): Train loss 2.972, Val loss 2.611
# Ep 1 (Step 002040): Train loss 2.851, Val loss 2.597
# Ep 1 (Step 002045): Train loss 2.538, Val loss 2.601
# Ep 1 (Step 002050): Train loss 2.882, Val loss 2.601
# Ep 1 (Step 002055): Train loss 2.898, Val loss 2.600
# Ep 1 (Step 002060): Train loss 2.548, Val loss 2.617
# Ep 1 (Step 002065): Train loss 2.940, Val loss 2.607
# Ep 1 (Step 002070): Train loss 2.700, Val loss 2.636
# Ep 1 (Step 002075): Train loss 3.181, Val loss 2.617
# Ep 1 (Step 002080): Train loss 2.773, Val loss 2.595
# Ep 1 (Step 002085): Train loss 2.873, Val loss 2.615
# Ep 1 (Step 002090): Train loss 3.103, Val loss 2.604
# Ep 1 (Step 002095): Train loss 2.922, Val loss 2.588
# Ep 1 (Step 002100): Train loss 2.753, Val loss 2.585
# Ep 1 (Step 002105): Train loss 2.700, Val loss 2.592
# Ep 1 (Step 002110): Train loss 2.550, Val loss 2.604
# Ep 1 (Step 002115): Train loss 3.022, Val loss 2.586
# Ep 1 (Step 002120): Train loss 2.837, Val loss 2.604
# Ep 1 (Step 002125): Train loss 2.850, Val loss 2.601
# Ep 1 (Step 002130): Train loss 3.177, Val loss 2.603
# Ep 1 (Step 002135): Train loss 2.674, Val loss 2.616
# Ep 1 (Step 002140): Train loss 3.045, Val loss 2.597
# Ep 1 (Step 002145): Train loss 2.605, Val loss 2.587
# Ep 1 (Step 002150): Train loss 2.785, Val loss 2.577
# Ep 1 (Step 002155): Train loss 2.698, Val loss 2.598
# Ep 1 (Step 002160): Train loss 2.836, Val loss 2.576
# Ep 1 (Step 002165): Train loss 2.648, Val loss 2.572
# Ep 1 (Step 002170): Train loss 2.563, Val loss 2.595
# Ep 1 (Step 002175): Train loss 2.611, Val loss 2.585
# Ep 1 (Step 002180): Train loss 2.789, Val loss 2.580
# Ep 1 (Step 002185): Train loss 2.680, Val loss 2.589
# Ep 1 (Step 002190): Train loss 2.839, Val loss 2.591
# Ep 1 (Step 002195): Train loss 2.821, Val loss 2.595
# Ep 1 (Step 002200): Train loss 2.697, Val loss 2.611
# Ep 1 (Step 002205): Train loss 2.727, Val loss 2.591
# Ep 1 (Step 002210): Train loss 2.643, Val loss 2.579
# Ep 1 (Step 002215): Train loss 2.958, Val loss 2.590
# Ep 1 (Step 002220): Train loss 2.643, Val loss 2.610
# Ep 1 (Step 002225): Train loss 2.762, Val loss 2.596
# Ep 1 (Step 002230): Train loss 2.655, Val loss 2.600
# Ep 1 (Step 002235): Train loss 3.050, Val loss 2.609
# Ep 1 (Step 002240): Train loss 2.551, Val loss 2.588
# Ep 1 (Step 002245): Train loss 2.604, Val loss 2.585
# Ep 1 (Step 002250): Train loss 3.004, Val loss 2.570
# Ep 1 (Step 002255): Train loss 2.813, Val loss 2.560
# Ep 1 (Step 002260): Train loss 2.697, Val loss 2.569
# Ep 1 (Step 002265): Train loss 3.039, Val loss 2.577
# Ep 1 (Step 002270): Train loss 2.876, Val loss 2.561
# Ep 1 (Step 002275): Train loss 2.752, Val loss 2.558
# Ep 1 (Step 002280): Train loss 2.632, Val loss 2.572
# Ep 1 (Step 002525): Train loss 2.789, Val loss 2.501
# Ep 1 (Step 002530): Train loss 2.609, Val loss 2.515
# Ep 1 (Step 002535): Train loss 2.845, Val loss 2.543
# Ep 1 (Step 002540): Train loss 2.681, Val loss 2.526
# Ep 1 (Step 002545): Train loss 2.633, Val loss 2.517
# Ep 1 (Step 002550): Train loss 2.734, Val loss 2.500
# Ep 1 (Step 002555): Train loss 2.627, Val loss 2.514
# Ep 1 (Step 002560): Train loss 2.673, Val loss 2.526
# Ep 1 (Step 002565): Train loss 2.639, Val loss 2.497
# Ep 1 (Step 002570): Train loss 2.685, Val loss 2.499
# Ep 1 (Step 002575): Train loss 2.980, Val loss 2.503
# Ep 1 (Step 002580): Train loss 2.699, Val loss 2.494
# Ep 1 (Step 002585): Train loss 2.668, Val loss 2.511
# Ep 1 (Step 002590): Train loss 2.677, Val loss 2.485
# Ep 1 (Step 002595): Train loss 2.653, Val loss 2.477
# Ep 1 (Step 002600): Train loss 2.491, Val loss 2.517
# Ep 1 (Step 002605): Train loss 2.461, Val loss 2.493
# Ep 1 (Step 002610): Train loss 2.631, Val loss 2.486
# Ep 1 (Step 002615): Train loss 2.593, Val loss 2.499
# Ep 1 (Step 002620): Train loss 2.800, Val loss 2.488
# Ep 1 (Step 002625): Train loss 2.664, Val loss 2.503
# Ep 1 (Step 002630): Train loss 2.596, Val loss 2.512
# Ep 1 (Step 002635): Train loss 2.698, Val loss 2.502
# Ep 1 (Step 002640): Train loss 2.583, Val loss 2.502
# Ep 1 (Step 002645): Train loss 2.574, Val loss 2.506
# Ep 1 (Step 002650): Train loss 2.766, Val loss 2.526
# Ep 1 (Step 002655): Train loss 2.498, Val loss 2.518
# Ep 1 (Step 002660): Train loss 2.603, Val loss 2.495
# Ep 1 (Step 002665): Train loss 2.344, Val loss 2.474
# Ep 1 (Step 002670): Train loss 2.634, Val loss 2.470
# Ep 1 (Step 002675): Train loss 2.464, Val loss 2.482
# Ep 1 (Step 002680): Train loss 2.707, Val loss 2.502
# Ep 1 (Step 002685): Train loss 2.459, Val loss 2.499
# Ep 1 (Step 002690): Train loss 2.742, Val loss 2.491
# Ep 1 (Step 002695): Train loss 2.806, Val loss 2.476
# Ep 1 (Step 002700): Train loss 2.545, Val loss 2.485
# Ep 1 (Step 002705): Train loss 2.732, Val loss 2.477
# Ep 1 (Step 002710): Train loss 2.538, Val loss 2.464
# Ep 1 (Step 002715): Train loss 2.414, Val loss 2.449
# Ep 1 (Step 002720): Train loss 2.628, Val loss 2.434
# Ep 1 (Step 002725): Train loss 2.683, Val loss 2.458
# Ep 1 (Step 002730): Train loss 2.793, Val loss 2.466
# Ep 1 (Step 002735): Train loss 2.522, Val loss 2.443
# Ep 1 (Step 002740): Train loss 2.647, Val loss 2.430
# Ep 1 (Step 002745): Train loss 2.584, Val loss 2.441
# Ep 1 (Step 002750): Train loss 2.623, Val loss 2.449
# Ep 1 (Step 002755): Train loss 2.749, Val loss 2.458
# Ep 1 (Step 002760): Train loss 2.648, Val loss 2.446
# Ep 1 (Step 003005): Train loss 2.534, Val loss 2.418
# Ep 1 (Step 003010): Train loss 2.525, Val loss 2.401
# Ep 1 (Step 003015): Train loss 2.412, Val loss 2.405
# Ep 1 (Step 003020): Train loss 2.449, Val loss 2.411
# Ep 1 (Step 003025): Train loss 2.509, Val loss 2.409
# Ep 1 (Step 003030): Train loss 2.665, Val loss 2.392
# Ep 1 (Step 003035): Train loss 2.541, Val loss 2.387
# Ep 1 (Step 003040): Train loss 2.362, Val loss 2.384
# Ep 1 (Step 003045): Train loss 2.455, Val loss 2.391
# Ep 1 (Step 003050): Train loss 2.533, Val loss 2.372
# Ep 1 (Step 003055): Train loss 2.461, Val loss 2.373
# Ep 1 (Step 003060): Train loss 2.439, Val loss 2.385
# Ep 1 (Step 003065): Train loss 2.669, Val loss 2.376
# Ep 1 (Step 003070): Train loss 2.468, Val loss 2.375
# Ep 1 (Step 003075): Train loss 2.458, Val loss 2.387
# Ep 1 (Step 003080): Train loss 2.389, Val loss 2.403
# Ep 1 (Step 003085): Train loss 2.469, Val loss 2.384
# Ep 1 (Step 003090): Train loss 2.361, Val loss 2.379
# Ep 1 (Step 003095): Train loss 2.468, Val loss 2.381
# Ep 1 (Step 003100): Train loss 2.204, Val loss 2.384
# Ep 1 (Step 003105): Train loss 3.046, Val loss 2.373
# Ep 1 (Step 003110): Train loss 2.858, Val loss 2.377
# Ep 1 (Step 003115): Train loss 2.619, Val loss 2.383
# Ep 1 (Step 003120): Train loss 2.522, Val loss 2.365
# Ep 1 (Step 003125): Train loss 2.678, Val loss 2.352
# Ep 1 (Step 003130): Train loss 2.535, Val loss 2.359
# Ep 1 (Step 003135): Train loss 2.693, Val loss 2.378
# Ep 1 (Step 003140): Train loss 2.440, Val loss 2.364
# Ep 1 (Step 003145): Train loss 2.818, Val loss 2.363
# Ep 1 (Step 003150): Train loss 2.384, Val loss 2.382
# Ep 1 (Step 003155): Train loss 2.519, Val loss 2.392
# Ep 1 (Step 003160): Train loss 2.512, Val loss 2.390
# Ep 1 (Step 003165): Train loss 2.415, Val loss 2.377
# Ep 1 (Step 003170): Train loss 2.806, Val loss 2.373
# Ep 1 (Step 003175): Train loss 2.611, Val loss 2.390
# Ep 1 (Step 003180): Train loss 2.636, Val loss 2.385
# Ep 1 (Step 003185): Train loss 2.507, Val loss 2.375
# Ep 1 (Step 003190): Train loss 2.528, Val loss 2.357
# Ep 1 (Step 003195): Train loss 2.275, Val loss 2.371
# Ep 1 (Step 003200): Train loss 2.745, Val loss 2.377
# Ep 1 (Step 003205): Train loss 2.756, Val loss 2.391
# Ep 1 (Step 003210): Train loss 2.340, Val loss 2.392
# Ep 1 (Step 003215): Train loss 2.833, Val loss 2.376
# Ep 1 (Step 003220): Train loss 2.855, Val loss 2.371
# Ep 1 (Step 003225): Train loss 2.640, Val loss 2.385
# Ep 1 (Step 003230): Train loss 2.656, Val loss 2.347
# Ep 1 (Step 003235): Train loss 2.796, Val loss 2.343
# Ep 1 (Step 003240): Train loss 2.425, Val loss 2.358
# Ep 1 (Step 003245): Train loss 2.325, Val loss 2.361
# Ep 1 (Step 003250): Train loss 2.603, Val loss 2.365
# Ep 1 (Step 003255): Train loss 2.512, Val loss 2.382
# Ep 1 (Step 003260): Train loss 2.442, Val loss 2.374
# Ep 1 (Step 003265): Train loss 2.683, Val loss 2.351
# Ep 1 (Step 003270): Train loss 2.445, Val loss 2.358
# Ep 1 (Step 003275): Train loss 2.239, Val loss 2.381
# Ep 1 (Step 003280): Train loss 2.263, Val loss 2.384
# Ep 1 (Step 003285): Train loss 2.666, Val loss 2.372
# Ep 1 (Step 003290): Train loss 2.491, Val loss 2.380
# Ep 1 (Step 003295): Train loss 2.473, Val loss 2.370
# Ep 1 (Step 003300): Train loss 2.441, Val loss 2.367
# Ep 1 (Step 003305): Train loss 2.621, Val loss 2.379
# Ep 1 (Step 003310): Train loss 2.393, Val loss 2.361
# Ep 1 (Step 003315): Train loss 2.347, Val loss 2.366
# Ep 1 (Step 003320): Train loss 2.257, Val loss 2.367
# Ep 1 (Step 003325): Train loss 2.264, Val loss 2.357
# Ep 1 (Step 003330): Train loss 2.305, Val loss 2.341
# Ep 1 (Step 003335): Train loss 2.363, Val loss 2.358
# Ep 1 (Step 003340): Train loss 2.841, Val loss 2.347
# Ep 1 (Step 003345): Train loss 2.492, Val loss 2.330
# Ep 1 (Step 003350): Train loss 2.654, Val loss 2.342
# Ep 1 (Step 003355): Train loss 2.475, Val loss 2.338
# Ep 1 (Step 003360): Train loss 2.675, Val loss 2.345
# Ep 1 (Step 003365): Train loss 2.546, Val loss 2.346
# Ep 1 (Step 003370): Train loss 2.755, Val loss 2.360
# Ep 1 (Step 003375): Train loss 2.762, Val loss 2.340
# Ep 1 (Step 003380): Train loss 2.679, Val loss 2.358
# Ep 1 (Step 003385): Train loss 2.755, Val loss 2.347
# Ep 1 (Step 003390): Train loss 2.720, Val loss 2.328
# Ep 1 (Step 003395): Train loss 2.388, Val loss 2.359
# Ep 1 (Step 003400): Train loss 2.558, Val loss 2.357
# Ep 1 (Step 003405): Train loss 2.490, Val loss 2.348
# Ep 1 (Step 003410): Train loss 2.381, Val loss 2.346
# Ep 1 (Step 003415): Train loss 2.596, Val loss 2.353
# Ep 1 (Step 003420): Train loss 2.468, Val loss 2.345
# Ep 1 (Step 003425): Train loss 2.277, Val loss 2.350
# Ep 1 (Step 003430): Train loss 2.567, Val loss 2.348
# Ep 1 (Step 003435): Train loss 2.406, Val loss 2.343
# Ep 1 (Step 003440): Train loss 2.628, Val loss 2.328
# Ep 1 (Step 003445): Train loss 2.219, Val loss 2.332
# Ep 1 (Step 003450): Train loss 2.560, Val loss 2.345
# Ep 1 (Step 003455): Train loss 2.624, Val loss 2.335
# Ep 1 (Step 003460): Train loss 3.005, Val loss 2.319
# Ep 1 (Step 003465): Train loss 2.387, Val loss 2.316
# Ep 1 (Step 003470): Train loss 2.621, Val loss 2.328
# Ep 1 (Step 003475): Train loss 2.377, Val loss 2.323
# Ep 1 (Step 003480): Train loss 2.640, Val loss 2.326
# Ep 1 (Step 003485): Train loss 2.390, Val loss 2.348
# Ep 1 (Step 003490): Train loss 2.657, Val loss 2.346
# Ep 1 (Step 003495): Train loss 2.448, Val loss 2.348
# Ep 1 (Step 003500): Train loss 2.391, Val loss 2.362
# Ep 1 (Step 003505): Train loss 2.236, Val loss 2.356
# Ep 1 (Step 003510): Train loss 2.457, Val loss 2.352
# Ep 1 (Step 003515): Train loss 2.296, Val loss 2.360
# Ep 1 (Step 003520): Train loss 2.293, Val loss 2.349
# Ep 1 (Step 003525): Train loss 2.361, Val loss 2.336
# Ep 1 (Step 003530): Train loss 2.386, Val loss 2.341
# Ep 1 (Step 003535): Train loss 2.532, Val loss 2.355
# Ep 1 (Step 003540): Train loss 2.483, Val loss 2.355
# Ep 1 (Step 003545): Train loss 2.262, Val loss 2.353
# Ep 1 (Step 003550): Train loss 2.766, Val loss 2.340
# Ep 1 (Step 003555): Train loss 2.194, Val loss 2.325
# Ep 1 (Step 003560): Train loss 2.463, Val loss 2.330
# Ep 1 (Step 003565): Train loss 2.539, Val loss 2.343
# Ep 1 (Step 003570): Train loss 2.364, Val loss 2.360
# Ep 1 (Step 003575): Train loss 2.275, Val loss 2.344
# Ep 1 (Step 003580): Train loss 2.650, Val loss 2.327
# Ep 1 (Step 003585): Train loss 2.343, Val loss 2.332
# Ep 1 (Step 003590): Train loss 2.363, Val loss 2.325
# Ep 1 (Step 003595): Train loss 2.216, Val loss 2.328
# Ep 1 (Step 003600): Train loss 2.664, Val loss 2.334
# Ep 1 (Step 003605): Train loss 2.303, Val loss 2.329
# Ep 1 (Step 003610): Train loss 2.631, Val loss 2.336
# Ep 1 (Step 003615): Train loss 2.500, Val loss 2.353
# Ep 1 (Step 003620): Train loss 2.747, Val loss 2.355
# Ep 1 (Step 003625): Train loss 2.200, Val loss 2.344
# Ep 1 (Step 003630): Train loss 2.389, Val loss 2.339
# Ep 1 (Step 003635): Train loss 2.613, Val loss 2.313
# Ep 1 (Step 003640): Train loss 2.381, Val loss 2.326
# Ep 1 (Step 003645): Train loss 2.342, Val loss 2.317
# Ep 1 (Step 003650): Train loss 2.543, Val loss 2.300
# Ep 1 (Step 003655): Train loss 2.333, Val loss 2.298
# Ep 1 (Step 003660): Train loss 2.632, Val loss 2.308
# Ep 1 (Step 003665): Train loss 2.381, Val loss 2.303
# Ep 1 (Step 003670): Train loss 2.155, Val loss 2.297
# Ep 1 (Step 003675): Train loss 2.290, Val loss 2.293
# Ep 1 (Step 003680): Train loss 2.390, Val loss 2.292
# Ep 1 (Step 003685): Train loss 2.535, Val loss 2.308
# Ep 1 (Step 003690): Train loss 2.183, Val loss 2.309
# Ep 1 (Step 003695): Train loss 2.348, Val loss 2.319
# Ep 1 (Step 003700): Train loss 2.567, Val loss 2.298
# Ep 1 (Step 003705): Train loss 2.474, Val loss 2.301
# Ep 1 (Step 003710): Train loss 2.384, Val loss 2.286
# Ep 1 (Step 003715): Train loss 2.483, Val loss 2.305
# Ep 1 (Step 003720): Train loss 2.316, Val loss 2.314
# Ep 1 (Step 003725): Train loss 2.289, Val loss 2.286
# Ep 1 (Step 003730): Train loss 2.579, Val loss 2.272
# Ep 1 (Step 003735): Train loss 2.363, Val loss 2.271
# Ep 1 (Step 003740): Train loss 2.244, Val loss 2.262
# Ep 1 (Step 003745): Train loss 2.502, Val loss 2.276
# Ep 1 (Step 003750): Train loss 2.393, Val loss 2.282
# Ep 1 (Step 003755): Train loss 2.589, Val loss 2.265
# Ep 1 (Step 003760): Train loss 2.294, Val loss 2.259
# Ep 1 (Step 003765): Train loss 2.527, Val loss 2.274
# Ep 1 (Step 003770): Train loss 2.250, Val loss 2.261
# Ep 1 (Step 003775): Train loss 2.324, Val loss 2.247
# Ep 1 (Step 003780): Train loss 2.117, Val loss 2.266
# Ep 1 (Step 003785): Train loss 2.437, Val loss 2.263
# Ep 1 (Step 003790): Train loss 2.320, Val loss 2.270
# Ep 1 (Step 003795): Train loss 2.636, Val loss 2.269
# Ep 1 (Step 003800): Train loss 2.314, Val loss 2.261
# Ep 1 (Step 003805): Train loss 2.387, Val loss 2.273
# Ep 1 (Step 003810): Train loss 2.572, Val loss 2.265
# Ep 1 (Step 003815): Train loss 2.309, Val loss 2.271
# Ep 1 (Step 003820): Train loss 2.545, Val loss 2.283
# Ep 1 (Step 003825): Train loss 2.311, Val loss 2.292
# Ep 1 (Step 003830): Train loss 2.589, Val loss 2.292
# Ep 1 (Step 003835): Train loss 2.457, Val loss 2.259
# Ep 1 (Step 003840): Train loss 2.603, Val loss 2.272
# Ep 1 (Step 003845): Train loss 2.534, Val loss 2.261
# Ep 1 (Step 003850): Train loss 2.323, Val loss 2.270
# Ep 1 (Step 003855): Train loss 2.614, Val loss 2.256
# Ep 1 (Step 003860): Train loss 2.187, Val loss 2.271
# Ep 1 (Step 003865): Train loss 2.311, Val loss 2.262
# Ep 1 (Step 003870): Train loss 2.591, Val loss 2.263
# Ep 1 (Step 003875): Train loss 2.631, Val loss 2.288
# Ep 1 (Step 003880): Train loss 2.633, Val loss 2.272
# Ep 1 (Step 003885): Train loss 2.505, Val loss 2.267
# Ep 1 (Step 003890): Train loss 2.696, Val loss 2.259
# Ep 1 (Step 003895): Train loss 2.210, Val loss 2.260
# Ep 1 (Step 003900): Train loss 2.552, Val loss 2.266
# Ep 1 (Step 003905): Train loss 2.529, Val loss 2.254
# Ep 1 (Step 003910): Train loss 2.346, Val loss 2.256
# Ep 1 (Step 003915): Train loss 2.324, Val loss 2.264
# Ep 1 (Step 003920): Train loss 2.514, Val loss 2.265
# Ep 1 (Step 003925): Train loss 2.381, Val loss 2.258
# Ep 1 (Step 003930): Train loss 2.338, Val loss 2.255
# Ep 1 (Step 003935): Train loss 2.258, Val loss 2.274
# Ep 1 (Step 003940): Train loss 2.139, Val loss 2.257
# Ep 1 (Step 003945): Train loss 2.361, Val loss 2.259
# Ep 1 (Step 003950): Train loss 2.446, Val loss 2.268
# Ep 1 (Step 003955): Train loss 2.624, Val loss 2.243
# Ep 1 (Step 003960): Train loss 2.469, Val loss 2.235
# Ep 4 (Step 018115): Train loss 1.383, Val loss 1.726
# Ep 4 (Step 018120): Train loss 1.470, Val loss 1.725
# Ep 4 (Step 018125): Train loss 1.740, Val loss 1.732
# Ep 4 (Step 018130): Train loss 1.586, Val loss 1.733
# Ep 4 (Step 018135): Train loss 1.504, Val loss 1.723
# Ep 4 (Step 018140): Train loss 1.618, Val loss 1.713
# Ep 4 (Step 018145): Train loss 1.556, Val loss 1.712
# Ep 4 (Step 018150): Train loss 1.449, Val loss 1.713
# Ep 4 (Step 018155): Train loss 1.465, Val loss 1.710
# Ep 4 (Step 018160): Train loss 1.543, Val loss 1.714
# Ep 4 (Step 018165): Train loss 1.885, Val loss 1.717
# Ep 4 (Step 018170): Train loss 1.518, Val loss 1.710
# Ep 4 (Step 018175): Train loss 1.496, Val loss 1.712
# Ep 4 (Step 018180): Train loss 1.782, Val loss 1.718
# Ep 4 (Step 018185): Train loss 1.868, Val loss 1.719
# Ep 4 (Step 018190): Train loss 1.513, Val loss 1.716
# Ep 4 (Step 018195): Train loss 1.586, Val loss 1.718
# Ep 4 (Step 018200): Train loss 1.570, Val loss 1.714
# Ep 4 (Step 018205): Train loss 1.428, Val loss 1.711
# Ep 4 (Step 018210): Train loss 1.597, Val loss 1.711
# Ep 4 (Step 018215): Train loss 1.496, Val loss 1.704
# Ep 4 (Step 018220): Train loss 1.630, Val loss 1.709
# Ep 4 (Step 018225): Train loss 1.835, Val loss 1.716
# Ep 4 (Step 018230): Train loss 1.696, Val loss 1.713
# Ep 4 (Step 018235): Train loss 1.562, Val loss 1.723
# Ep 4 (Step 018240): Train loss 1.724, Val loss 1.726
# Ep 4 (Step 018245): Train loss 1.703, Val loss 1.726
# Ep 4 (Step 018250): Train loss 1.480, Val loss 1.722

# %%
from google.colab import drive
drive.mount('/content/drive')
GPT_CONFIG_124M = {
    "vocab_size": 50257,    # Vocabulary size
    "context_length": 256,  # context length
    "emb_dim": 768,         # Embedding dimension
    "n_heads": 12,          # Number of attention heads
    "n_layers": 12,         # Number of layers
    "drop_rate": 0.1,       # Dropout rate
    "qkv_bias": False       # Query-key-value bias
}
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = GPTModel(GPT_CONFIG_124M)
model.load_state_dict(torch.load('/content/drive/MyDrive/model_weights.pth',weights_only=True,map_location='cpu'))
model.to(device)
tokenizer = tiktoken.get_encoding("gpt2")
text = generate_and_print_sample(model,tokenizer,device,"lily went out")

len(text)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# lily went out to play. She saw a big, fluffy cloud in the sky. She wanted to go closer to see it.  Lily's mom said, "Lily, let's go see the cloud. It's a big cloud that can hurt us." Lily was scared, but she trusted her mom. They walked slowly to the cloud.  When they got closer, they saw that the cloud was just a cloud. Lily was so happy to see the cloud that she hugged her mom.
# 382

# %%
text = generate_and_print_sample(model,tokenizer,device,"going out to the sea")

len(text)
# Out:
# going out to the sea.  The little girl was so happy and she hugged her mom. She was so proud of her mom and she knew she had done a great job.Once upon a time, there was a little girl named Lily. She loved to play outside in the rain. One day, she went outside to play and it was very cold. She put on her raincoat and boots and boots and boots.   Lily's mommy said, "Let's go inside and warm up."
# 397
